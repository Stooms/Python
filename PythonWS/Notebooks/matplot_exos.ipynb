# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.colors as clr
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
print("----------------------- EXERCICE 1 -----------------------")
# Out:
# ----------------------- EXERCICE 1 -----------------------

# %%
n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)

plt.axes([0.025,0.025,0.95,0.95])

plt.plot(X, Y+1, color='blue', alpha=1.00)
plt.fill_between(X,1.0,Y+1,color='lightskyblue')


plt.plot(X, Y-1, color='blue', alpha=1.00)
plt.fill_between(X,-1.0,Y-1,where=(Y-1>-1),color='lightskyblue')
plt.fill_between(X,-1.0,Y-1,where=(Y-1<-1),color='salmon')

plt.xlim(-np.pi,np.pi), plt.xticks([])
plt.ylim(-2.5,2.5), plt.yticks([])

plt.show()

# %%
print("----------------------- EXERCICE 2 -----------------------")
# Out:
# ----------------------- EXERCICE 2 -----------------------

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
T=np.arctan2(Y,X)

plt.axes([0.025,0.025,0.95,0.95])
plt.scatter(X,Y,s=75,cmap=T,alpha=0.5)

plt.xlim(-1.5,1.5), plt.xticks([])
plt.ylim(-1.5,1.5), plt.yticks([])

plt.show()

# %%
print("----------------------- EXERCICE 3 -----------------------")
# Out:
# ----------------------- EXERCICE 3 -----------------------

# %%
n = 12
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)

plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

for x,y1,y2 in zip(X,Y1,Y2):
    plt.text(x, y1+0.05, '%.2f' % y1, ha='center', va= 'bottom')
    plt.text(x, -y2-0.18, '%.2f' % y2, ha='center', va= 'bottom')

    
plt.xticks([]), plt.yticks([])
plt.ylim(-1.25,+1.25)
plt.show()

# %%
print("----------------------- EXERCICE 4 -----------------------")
# Out:
# ----------------------- EXERCICE 4 -----------------------

# %%
def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
X,Y = np.meshgrid(x,y)

plt.axes([0.025,0.025,0.95,0.95])
plt.contourf(X, Y, f(X,Y), 8, alpha=.75, cmap=cm.hot)
C=plt.contour(X, Y, f(X,Y), 8, colors='black', linewidths=np.arange(.5, 2, .5))
plt.clabel(C, inline=1, fontsize=10)

plt.xticks([]), plt.yticks([])

plt.show()

# %%
print("----------------------- EXERCICE 5 -----------------------")
# Out:
# ----------------------- EXERCICE 5 -----------------------

# %%
def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 10
x = np.linspace(-3,3,4*n)
y = np.linspace(-3,3,3*n)
X,Y = np.meshgrid(x,y)

plt.axes([0.025,0.025,0.95,0.95])

plt.xticks([]), plt.yticks([])
plt.imshow(f(X,Y), interpolation='nearest',cmap='bone',origin='lower')
plt.colorbar(shrink=0.92)
plt.show()

# %%
print("----------------------- EXERCICE 6 -----------------------")

# %%
n = 8
X,Y = np.mgrid[0:n,0:n]
T = np.arctan2(Y-n/2.0, X-n/2.0)
R = 10+np.sqrt((Y-n/2.0)**2+(X-n/2.0)**2)
U,V = R*np.cos(T), R*np.sin(T)

plt.axes([0.025,0.025,0.95,0.95])
plt.quiver(X,Y,U,V,R, alpha=.5)
plt.quiver(X,Y,U,V, edgecolor='k', facecolor='None', linewidth=.5)

plt.xlim(-1,n), plt.xticks([])
plt.ylim(-1,n), plt.yticks([])

# savefig('../figures/quiver_ex.png',dpi=48)
plt.show()

# %%
n = 20
Z = np.ones(n)
Z[-1] *= 2

plt.axes([0.025,0.025,0.95,0.95])
color=['%f' % (i/float(n)) for i in range(n)]
plt.pie(Z, explode=Z*.05, colors=clr.hsv_to_rgb(color))
plt.gca().set_aspect('equal')
plt.xticks([]), plt.yticks([])

# savefig('../figures/pie_ex.png',dpi=48)
plt.show()
# Out:
# ['0.000000', '0.050000', '0.100000', '0.150000', '0.200000', '0.250000', '0.300000', '0.350000', '0.400000', '0.450000', '0.500000', '0.550000', '0.600000', '0.650000', '0.700000', '0.750000', '0.800000', '0.850000', '0.900000', '0.950000']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-223-f18f4fcbd084> in <module>
#       6 color=['%f' % (i/float(n)) for i in range(n)]
#       7 print(color)
# ...
